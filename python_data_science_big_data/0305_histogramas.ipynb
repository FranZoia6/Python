# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("C:\\Users\\Fran Zoia\\Documents\\Cursos\\Python\\python_data_science_big_data\\base_datos_2008.csv")

# %%
df.dropna(inplace=True, subset=  ["ArrDelay", "DepDelay", "Distance"])

# %%
sns.displot(df["Distance"], kde = False, bins= 100)

# %%
sns.kdeplot(df["ArrDelay"])
sns.kdeplot(df["DepDelay"])
plt.xlim(-300,300)
# Out:
# (-300.0, 300.0)

# %%
df2 = df[df["Origin"].isin(["ATL","HOU", "IND"])].sample(frac=1).head(500)

# %%
sns.boxenplot(x= "DepDelay", y= "Origin", data =df2)
plt.xlim(-20,150)
# Out:
# (-20.0, 150.0)
