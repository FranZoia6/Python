# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as ptl 

df = pd.read_csv("C:\\Users\\Fran Zoia\\Documents\\Cursos\\Python\\python_data_science_big_data\\base_datos_2008.csv", nrows=10000)

# %%
data  = np.unique(df.Cancelled, return_counts= True)
data
# Out:
# (array([0, 1], dtype=int64), array([9837,  163], dtype=int64))

# %%
ptl.pie(x = data[1],
            labels=data[0], colors=["Red", "Green"], 
            shadow= True,
            startangle= 90,
            radius= 2)
ptl.show()
